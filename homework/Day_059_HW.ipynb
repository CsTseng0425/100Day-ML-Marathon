# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
# !pip3 install --user sklearn
# !pip3 install --user --upgrade matplotlib
# Out:
# Requirement already satisfied: sklearn in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from sklearn) (0.21.2)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.16.4)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.3.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already up-to-date: matplotlib in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (3.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (1.16.4)
# Requirement already satisfied, skipping upgrade: six in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from cycler>=0.10->matplotlib) (1.12.0)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (40.8.0)

# %%
from sklearn import datasets

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %%
#y

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition

np.random.seed(5)
# %matplotlib inline

# %%
#設定 模型 估計參數
centers = [[1, 1], [-1, -1], [1, -1]]
pca = decomposition.PCA(n_components=3)

# %%
#資料建模 並 視覺化 結果
pca.fit(X)
X = pca.transform(X)

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()


for name, label in [('No_1', 0), ('No_2', 1), ('No_3', 2)]:
    ax.text3D(X[y == label, 0].mean()+2,
              X[y == label, 1].mean() + 6,
              X[y == label, 2].mean()+ 6, name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

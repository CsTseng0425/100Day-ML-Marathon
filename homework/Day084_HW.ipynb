# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp_BN(input_shape, output_units=10, num_neurons=[2, 16, 32, 128, 256]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
from keras.layers import Dropout
def build_mlp_Dp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.1):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp_BN(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0809 17:13:22.374620  2980 deprecation_wrapper.py:119] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0809 17:13:22.414638  2980 deprecation_wrapper.py:119] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0809 17:13:22.426604  2980 deprecation_wrapper.py:119] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0809 17:13:22.513734  2980 deprecation_wrapper.py:119] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0809 17:13:22.783183  2980 deprecation_wrapper.py:119] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0809 17:13:22.787487  2980 deprecation_wrapper.py:119] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0809 17:13:22.872489  2980 deprecation.py:323] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 2)                 6146
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2)                 8
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 16)                48
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16)                64
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                544
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 128)               4224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 256)               33024
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 48,292
# Trainable params: 47,424
# Non-trainable params: 868
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3561 - acc: 0.1686 - val_loss: 2.3527 - val_acc: 0.1892
# Epoch 2/50
# 50000/50000 [==============================] - 2s 39us/step - loss: 2.0387 - acc: 0.2445 - val_loss: 2.0370 - val_acc: 0.2456
# Epoch 3/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.9644 - acc: 0.2628 - val_loss: 1.9581 - val_acc: 0.2721
# Epoch 4/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.9404 - acc: 0.2719 - val_loss: 1.9394 - val_acc: 0.2695
# Epoch 5/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.9277 - acc: 0.2721 - val_loss: 1.9377 - val_acc: 0.2714
# Epoch 6/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.9197 - acc: 0.2754 - val_loss: 1.9216 - val_acc: 0.2703
# Epoch 7/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.9132 - acc: 0.2771 - val_loss: 1.9159 - val_acc: 0.2752
# Epoch 8/50
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.9074 - acc: 0.2796 - val_loss: 1.9250 - val_acc: 0.2691
# Epoch 9/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.9042 - acc: 0.2794 - val_loss: 1.9081 - val_acc: 0.2771
# Epoch 10/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.9006 - acc: 0.2811 - val_loss: 1.9010 - val_acc: 0.2819
# Epoch 11/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8963 - acc: 0.2800 - val_loss: 1.9037 - val_acc: 0.2772
# Epoch 12/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8954 - acc: 0.2835 - val_loss: 1.8988 - val_acc: 0.2781
# Epoch 13/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8932 - acc: 0.2817 - val_loss: 1.9019 - val_acc: 0.2785
# Epoch 14/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8912 - acc: 0.2856 - val_loss: 1.8943 - val_acc: 0.2780
# Epoch 15/50
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.8890 - acc: 0.2863 - val_loss: 1.8927 - val_acc: 0.2781
# Epoch 16/50
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.8865 - acc: 0.2862 - val_loss: 1.8928 - val_acc: 0.2785
# Epoch 17/50
# 50000/50000 [==============================] - 2s 47us/step - loss: 1.8849 - acc: 0.2878 - val_loss: 1.8922 - val_acc: 0.2805
# Epoch 18/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8837 - acc: 0.2875 - val_loss: 1.8913 - val_acc: 0.2798
# Epoch 19/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8818 - acc: 0.2898 - val_loss: 1.9043 - val_acc: 0.2734
# Epoch 20/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8815 - acc: 0.2884 - val_loss: 1.8904 - val_acc: 0.2760
# Epoch 21/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8804 - acc: 0.2885 - val_loss: 1.8996 - val_acc: 0.2753
# Epoch 22/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8791 - acc: 0.2896 - val_loss: 1.8922 - val_acc: 0.2761
# Epoch 23/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8785 - acc: 0.2890 - val_loss: 1.8896 - val_acc: 0.2841
# Epoch 24/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8763 - acc: 0.2896 - val_loss: 1.8871 - val_acc: 0.2786
# Epoch 25/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8761 - acc: 0.2901 - val_loss: 1.8866 - val_acc: 0.2811
# Epoch 26/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8750 - acc: 0.2899 - val_loss: 1.8950 - val_acc: 0.2729
# Epoch 27/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8747 - acc: 0.2922 - val_loss: 1.8914 - val_acc: 0.2741
# Epoch 28/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8731 - acc: 0.2897 - val_loss: 1.8913 - val_acc: 0.2774
# Epoch 29/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8716 - acc: 0.2922 - val_loss: 1.8887 - val_acc: 0.2773
# Epoch 30/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8717 - acc: 0.2920 - val_loss: 1.8894 - val_acc: 0.2784
# Epoch 31/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8708 - acc: 0.2932 - val_loss: 1.8844 - val_acc: 0.2799
# Epoch 32/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8698 - acc: 0.2913 - val_loss: 1.8828 - val_acc: 0.2820
# Epoch 33/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8686 - acc: 0.2940 - val_loss: 1.8904 - val_acc: 0.2841
# Epoch 34/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8683 - acc: 0.2933 - val_loss: 1.8843 - val_acc: 0.2766
# Epoch 35/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8678 - acc: 0.2925 - val_loss: 1.8831 - val_acc: 0.2759
# Epoch 36/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8670 - acc: 0.2928 - val_loss: 1.8876 - val_acc: 0.2802
# Epoch 37/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8670 - acc: 0.2945 - val_loss: 1.8921 - val_acc: 0.2773
# Epoch 38/50
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.8659 - acc: 0.2943 - val_loss: 1.8839 - val_acc: 0.2793
# Epoch 39/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8643 - acc: 0.2967 - val_loss: 1.8981 - val_acc: 0.2746
# Epoch 40/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8656 - acc: 0.2948 - val_loss: 1.8822 - val_acc: 0.2819
# Epoch 41/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8641 - acc: 0.2964 - val_loss: 1.8864 - val_acc: 0.2820
# Epoch 42/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8636 - acc: 0.2964 - val_loss: 1.8875 - val_acc: 0.2833
# Epoch 43/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8632 - acc: 0.2966 - val_loss: 1.8855 - val_acc: 0.2784
# Epoch 44/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8626 - acc: 0.2984 - val_loss: 1.8844 - val_acc: 0.2799
# Epoch 45/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8617 - acc: 0.2989 - val_loss: 1.8897 - val_acc: 0.2807
# Epoch 46/50
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.8618 - acc: 0.2968 - val_loss: 1.8879 - val_acc: 0.2824
# Epoch 47/50
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.8605 - acc: 0.2971 - val_loss: 1.8929 - val_acc: 0.2783
# Epoch 48/50
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8601 - acc: 0.3003 - val_loss: 1.8885 - val_acc: 0.2803
# Epoch 49/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.8591 - acc: 0.2990 - val_loss: 1.8855 - val_acc: 0.2831
# Epoch 50/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.8586 - acc: 0.3019 - val_loss: 1.8849 - val_acc: 0.2816
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-204436bd44a6> in <module>
#      20 valid_acc = model.history.history["val_acc"]
#      21
# ---> 22 exp_name_tag = "BatchNormalization-%s" % str(dropout_rate)
#      23 results[exp_name_tag] = {'train-loss': train_loss,
#      24                          'valid-loss': valid_loss,
#
# NameError: name 'dropout_rate' is not defined

# %%
exp_name_tag = "BatchNormalization-" 
results[exp_name_tag] = {'train-loss': train_loss,
                         'valid-loss': valid_loss,
                         'train-acc': train_acc,
                         'valid-acc': valid_acc}

# %%
model = build_mlp_Dp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

exp_name_tag = "dropout_rate-%s" % str(0.1)
results[exp_name_tag] = {'train-loss': train_loss,
                         'valid-loss': valid_loss,
                         'train-acc': train_acc,
                         'valid-acc': valid_acc}
# Out:
# W0809 17:17:03.847196  2980 deprecation.py:506] From c:\users\susan01\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 2.1859 - acc: 0.1939 - val_loss: 1.9401 - val_acc: 0.3091
# Epoch 2/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.8946 - acc: 0.3143 - val_loss: 1.7924 - val_acc: 0.3578
# Epoch 3/50
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.7827 - acc: 0.3605 - val_loss: 1.7076 - val_acc: 0.3836
# Epoch 4/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.7179 - acc: 0.3814 - val_loss: 1.6475 - val_acc: 0.4125
# Epoch 5/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.6715 - acc: 0.4027 - val_loss: 1.5847 - val_acc: 0.4384
# Epoch 6/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.6174 - acc: 0.4235 - val_loss: 1.5347 - val_acc: 0.4478
# Epoch 7/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.5877 - acc: 0.4308 - val_loss: 1.5342 - val_acc: 0.4555
# Epoch 8/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.5537 - acc: 0.4449 - val_loss: 1.5104 - val_acc: 0.4584
# Epoch 9/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.5399 - acc: 0.4539 - val_loss: 1.5080 - val_acc: 0.4630
# Epoch 10/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.5091 - acc: 0.4628 - val_loss: 1.4863 - val_acc: 0.4702
# Epoch 11/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.4845 - acc: 0.4703 - val_loss: 1.4534 - val_acc: 0.4851
# Epoch 12/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.4672 - acc: 0.4772 - val_loss: 1.4400 - val_acc: 0.4840
# Epoch 13/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.4481 - acc: 0.4841 - val_loss: 1.4373 - val_acc: 0.4904
# Epoch 14/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.4350 - acc: 0.4885 - val_loss: 1.4232 - val_acc: 0.4921
# Epoch 15/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.4167 - acc: 0.4943 - val_loss: 1.3934 - val_acc: 0.5017
# Epoch 16/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.4081 - acc: 0.4994 - val_loss: 1.4104 - val_acc: 0.4973
# Epoch 17/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.3981 - acc: 0.5023 - val_loss: 1.3936 - val_acc: 0.4977
# Epoch 18/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 1.3786 - acc: 0.5090 - val_loss: 1.3786 - val_acc: 0.5102
# Epoch 19/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.3614 - acc: 0.5146 - val_loss: 1.3746 - val_acc: 0.5067
# Epoch 20/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.3639 - acc: 0.5138 - val_loss: 1.3983 - val_acc: 0.4967
# Epoch 21/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.3473 - acc: 0.5225 - val_loss: 1.3785 - val_acc: 0.5068
# Epoch 22/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.3275 - acc: 0.5267 - val_loss: 1.3517 - val_acc: 0.5173
# Epoch 23/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.3162 - acc: 0.5317 - val_loss: 1.3587 - val_acc: 0.5139
# Epoch 24/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 1.3113 - acc: 0.5315 - val_loss: 1.3531 - val_acc: 0.5153
# Epoch 25/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.2975 - acc: 0.5374 - val_loss: 1.3640 - val_acc: 0.5153
# Epoch 26/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.2847 - acc: 0.5408 - val_loss: 1.3366 - val_acc: 0.5282
# Epoch 27/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.2786 - acc: 0.5448 - val_loss: 1.3592 - val_acc: 0.5157
# Epoch 28/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 1.2585 - acc: 0.5512 - val_loss: 1.3136 - val_acc: 0.5303
# Epoch 29/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.2499 - acc: 0.5542 - val_loss: 1.3265 - val_acc: 0.5302
# Epoch 30/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.2480 - acc: 0.5530 - val_loss: 1.3197 - val_acc: 0.5301
# Epoch 31/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.2362 - acc: 0.5570 - val_loss: 1.3205 - val_acc: 0.5288
# Epoch 32/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.2134 - acc: 0.5661 - val_loss: 1.3327 - val_acc: 0.5230
# Epoch 33/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.2101 - acc: 0.5671 - val_loss: 1.3123 - val_acc: 0.5334
# Epoch 34/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.1976 - acc: 0.5705 - val_loss: 1.2971 - val_acc: 0.5378
# Epoch 35/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.2044 - acc: 0.5673 - val_loss: 1.3083 - val_acc: 0.5317
# Epoch 36/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.1961 - acc: 0.5720 - val_loss: 1.3085 - val_acc: 0.5358
# Epoch 37/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.1870 - acc: 0.5742 - val_loss: 1.3029 - val_acc: 0.5413
# Epoch 38/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.1686 - acc: 0.5815 - val_loss: 1.2831 - val_acc: 0.5447
# Epoch 39/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.1742 - acc: 0.5819 - val_loss: 1.3104 - val_acc: 0.5307
# Epoch 40/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.1650 - acc: 0.5832 - val_loss: 1.3038 - val_acc: 0.5331
# Epoch 41/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.1521 - acc: 0.5885 - val_loss: 1.2947 - val_acc: 0.5427
# Epoch 42/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.1399 - acc: 0.5933 - val_loss: 1.2878 - val_acc: 0.5408
# Epoch 43/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 1.1330 - acc: 0.5928 - val_loss: 1.3005 - val_acc: 0.5381
# Epoch 44/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.1202 - acc: 0.6002 - val_loss: 1.3094 - val_acc: 0.5416
# Epoch 45/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.1276 - acc: 0.5973 - val_loss: 1.3039 - val_acc: 0.5402
# Epoch 46/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.1204 - acc: 0.5976 - val_loss: 1.2945 - val_acc: 0.5464
# Epoch 47/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 1.1051 - acc: 0.6044 - val_loss: 1.2904 - val_acc: 0.5477
# Epoch 48/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.0978 - acc: 0.6074 - val_loss: 1.2840 - val_acc: 0.5489
# Epoch 49/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.0858 - acc: 0.6111 - val_loss: 1.2946 - val_acc: 0.5417
# Epoch 50/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.0896 - acc: 0.6104 - val_loss: 1.2842 - val_acc: 0.5400

# %%
from keras.regularizers import l1
def build_mlp_l1(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_ratio=1e-8):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1), 
                                   kernel_regularizer=l1(l1_ratio))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1),
                                   kernel_regularizer=l1(l1_ratio))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
keras.backend.clear_session() # 把舊的 Graph 清掉
#print("Experiment with Regulizer = %.6f" % (regulizer_ratio))
model = build_mlp_l1(input_shape=x_train.shape[1:], l1_ratio=1e-8)
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 2.2260 - acc: 0.1828 - val_loss: 2.1217 - val_acc: 0.2566
# Epoch 2/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 2.0512 - acc: 0.2757 - val_loss: 1.9859 - val_acc: 0.2996
# Epoch 3/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.9445 - acc: 0.3175 - val_loss: 1.9048 - val_acc: 0.3363
# Epoch 4/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.8770 - acc: 0.3467 - val_loss: 1.8518 - val_acc: 0.3558
# Epoch 5/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.8324 - acc: 0.3605 - val_loss: 1.8156 - val_acc: 0.3686
# Epoch 6/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.7992 - acc: 0.3724 - val_loss: 1.7843 - val_acc: 0.3820
# Epoch 7/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.7713 - acc: 0.3825 - val_loss: 1.7606 - val_acc: 0.3899
# Epoch 8/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.7474 - acc: 0.3909 - val_loss: 1.7402 - val_acc: 0.3957
# Epoch 9/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.7262 - acc: 0.3984 - val_loss: 1.7177 - val_acc: 0.4061
# Epoch 10/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.7071 - acc: 0.4042 - val_loss: 1.7021 - val_acc: 0.4080
# Epoch 11/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.6902 - acc: 0.4106 - val_loss: 1.6858 - val_acc: 0.4127
# Epoch 12/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.6745 - acc: 0.4159 - val_loss: 1.6721 - val_acc: 0.4163
# Epoch 13/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.6595 - acc: 0.4234 - val_loss: 1.6579 - val_acc: 0.4206
# Epoch 14/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.6450 - acc: 0.4257 - val_loss: 1.6439 - val_acc: 0.4284
# Epoch 15/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.6317 - acc: 0.4304 - val_loss: 1.6353 - val_acc: 0.4335
# Epoch 16/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.6189 - acc: 0.4361 - val_loss: 1.6204 - val_acc: 0.4369
# Epoch 17/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.6076 - acc: 0.4389 - val_loss: 1.6124 - val_acc: 0.4401
# Epoch 18/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.5952 - acc: 0.4439 - val_loss: 1.6019 - val_acc: 0.4460
# Epoch 19/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.5840 - acc: 0.4480 - val_loss: 1.5900 - val_acc: 0.4481
# Epoch 20/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.5733 - acc: 0.4507 - val_loss: 1.5855 - val_acc: 0.4463
# Epoch 21/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.5633 - acc: 0.4546 - val_loss: 1.5737 - val_acc: 0.4540
# Epoch 22/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.5533 - acc: 0.4580 - val_loss: 1.5707 - val_acc: 0.4513
# Epoch 23/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.5439 - acc: 0.4614 - val_loss: 1.5585 - val_acc: 0.4582
# Epoch 24/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.5345 - acc: 0.4648 - val_loss: 1.5525 - val_acc: 0.4606
# Epoch 25/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.5256 - acc: 0.4679 - val_loss: 1.5472 - val_acc: 0.4630
# Epoch 26/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.5166 - acc: 0.4707 - val_loss: 1.5372 - val_acc: 0.4638
# Epoch 27/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.5081 - acc: 0.4737 - val_loss: 1.5310 - val_acc: 0.4658
# Epoch 28/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.4999 - acc: 0.4775 - val_loss: 1.5261 - val_acc: 0.4620
# Epoch 29/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.4923 - acc: 0.4787 - val_loss: 1.5162 - val_acc: 0.4686
# Epoch 30/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.4839 - acc: 0.4825 - val_loss: 1.5159 - val_acc: 0.4694
# Epoch 31/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4759 - acc: 0.4854 - val_loss: 1.5049 - val_acc: 0.4705
# Epoch 32/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.4681 - acc: 0.4882 - val_loss: 1.4999 - val_acc: 0.4721
# Epoch 33/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.4607 - acc: 0.4900 - val_loss: 1.4940 - val_acc: 0.4767
# Epoch 34/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.4539 - acc: 0.4938 - val_loss: 1.4904 - val_acc: 0.4758
# Epoch 35/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.4461 - acc: 0.4952 - val_loss: 1.4830 - val_acc: 0.4740
# Epoch 36/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.4394 - acc: 0.4986 - val_loss: 1.4799 - val_acc: 0.4764
# Epoch 37/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.4324 - acc: 0.5003 - val_loss: 1.4754 - val_acc: 0.4784
# Epoch 38/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.4259 - acc: 0.5027 - val_loss: 1.4676 - val_acc: 0.4830
# Epoch 39/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.4182 - acc: 0.5053 - val_loss: 1.4654 - val_acc: 0.4842
# Epoch 40/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4116 - acc: 0.5064 - val_loss: 1.4606 - val_acc: 0.4835
# Epoch 41/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.4054 - acc: 0.5088 - val_loss: 1.4558 - val_acc: 0.4872
# Epoch 42/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.3990 - acc: 0.5120 - val_loss: 1.4503 - val_acc: 0.4882
# Epoch 43/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.3912 - acc: 0.5133 - val_loss: 1.4492 - val_acc: 0.4881
# Epoch 44/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.3854 - acc: 0.5168 - val_loss: 1.4436 - val_acc: 0.4911
# Epoch 45/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.3792 - acc: 0.5180 - val_loss: 1.4471 - val_acc: 0.4874
# Epoch 46/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.3733 - acc: 0.5210 - val_loss: 1.4351 - val_acc: 0.4967
# Epoch 47/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.3664 - acc: 0.5227 - val_loss: 1.4334 - val_acc: 0.4925
# Epoch 48/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3609 - acc: 0.5256 - val_loss: 1.4286 - val_acc: 0.4960
# Epoch 49/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.3538 - acc: 0.5260 - val_loss: 1.4254 - val_acc: 0.4957
# Epoch 50/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.3487 - acc: 0.5295 - val_loss: 1.4226 - val_acc: 0.4973
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-7af05066b5b2> in <module>
#      18 valid_acc = model.history.history["val_acc"]
#      19
# ---> 20 exp_name_tag = "exp-l1-%s" % str(regulizer_ratio)
#      21 results[exp_name_tag] = {'train-loss': train_loss,
#      22                          'valid-loss': valid_loss,
#
# NameError: name 'regulizer_ratio' is not defined

# %%
exp_name_tag = "exp-l1-%s" % str(1e-8)
results[exp_name_tag] = {'train-loss': train_loss,
                         'valid-loss': valid_loss,
                         'train-acc': train_acc,
                         'valid-acc': valid_acc}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
